# %%
import torchvision
from torchvision import datasets, transforms
import numpy as np
import torch
import torch.nn as nn
import pickle
from PIL import Image
import requests
from io import BytesIO
import urllib.request as url_req
from utils import urltoImg
import json

# %%
def get_model(device):
    model = torchvision.models.vgg11(pretrained=True)
    model.to(device)
    model.eval()
    return model

# %%
class Data(object):
    def __init__(self,model,device,testClassList,key):
        self.model = model
        self.device = device
        self.testClassList = testClassList
        self.id_label_map = pickle.load(open('pickled_id_label_imagenet_map', 'rb')) # load mapping as dict
        self.file_key = key
        
    def query_class_data(self,idx): 
        
        idx_id = self.id_label_map[idx]['id']
        wnid = str('n')+str(idx_id.split('-')[0])
        # print(wnid)
        synset_url = 'http://www.image-net.org/api/text/imagenet.synset.geturls?wnid='+str(wnid)
        # print(synset_url)
        urls = requests.get(synset_url).text.split('\r\n')     #clean for valid url
        label_class = self.id_label_map[idx]['label']               # get class name for given idx
        # print(label_class)
        return urls
        
    
    def preprocess_data(self,img):
#         for idx in self.testClassList:
#             urls = query_class_data(idx)
#             print(idx,len(urls))
        normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
        preprocess = transforms.Compose([transforms.Resize(256),
           transforms.CenterCrop(224),
           transforms.ToTensor(),
           normalize])
        
        return preprocess(img)
    
    def testModel(self,img,label):
        img_tsor = self.preprocess_data(img)
        img_tsor.unsqueeze_(0)
        img_tsor = img_tsor.to(self.device)

        label = torch.tensor(label,requires_grad=False)
        label = label.to(self.device)

        criterion = nn.CrossEntropyLoss()
        print(img_tsor.size())
        output = self.model(img_tsor)
        _,pred = torch.max(output,1)
        img_tsor.squeeze_(0)
#         imshow(img_tsor,wnid)
        org_label = float(label)
        output_idx = float(pred.cpu())
        output_class = self.id_label_map[float(pred.cpu())]['label']
        print('Original label = ',org_label)
        print('Output idx and class =',output_idx,',',output_class)
        return org_label,output_idx
    
            
    def make_valid_url_list(self):
        valid_urls = {}
        for idx in self.testClassList:
            urls = self.query_class_data(idx)
            np.random.shuffle(urls)
            i = 0
            valid_urls[idx] = []
            img = None
            flag = 0
            while (i<len(urls)):
                if (len(valid_urls[idx])==5):
                    break
                try:
                    var = url_req.urlopen(urls[i])
                    redirected_url = var.geturl()
                    if (str(redirected_url.split('/')[-1].split('.')[0]) == 'photo_unavailable'):   # this always results in 'photo_unavailable' if photo no longer exists
                        print(urls[i])
                        print('No photo')
                    else:
                        img = urltoImg(urls[i])
                        flag=1
                except:
                    print(urls[i])
                    print('Invalid url')
                
                if(flag==1):
                    orig_label,pred_label = self.testModel(img,idx)
                    if(orig_label != pred_label):
                        print('Diff label',i)
    
                    else:
                        print('Valid_url',i)
                        valid_urls[idx].append(urls[i])
                flag=0 
                i+=1
            file_name = str('valid_urls')+str(key)+str('.txt')
            with open(file_name,'a+') as f:
                f.write(json.dumps(valid_urls))
        return valid_urls

# %%
# class_id_arr1 = [8,9,21,31,35,49,63,75,84,86]
# class_id_arr2 = [93,100,105,113,121,130,144,148,151,282]
# class_id_arr3 = [293,295,298,309,311,314,360,417,430]
# class_id_arr4 = [438,457,470,480,491,543,546,568,578,587,609]
# class_id_arr5 = [620,629,637,668,696,706,721,773,806,845]

# len(class_id_arr)

# %%
# device = torch.device('cuda')

# model = get_model(device)

# %%
# key = 4
# dset = Data(model,device,class_id_arr4,key)
# val_urls = dset.make_valid_url_list()
# Out:
# http://html.rincondelvago.com/000286772.png
# Invalid url
# http://farm5.static.flickr.com/4017/4350136280_cdba608b25.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  438.0
# Output idx and class = 438.0 , beaker
# Valid_url 1
# http://farm3.static.flickr.com/2039/2037875598_27d4b6cc7b.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  438.0
# Output idx and class = 438.0 , beaker
# Valid_url 2
# http://farm4.static.flickr.com/3370/3199903331_12d0f604bd.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  438.0
# Output idx and class = 441.0 , beer glass
# Diff label 3
# http://www.cranberryinstitute.org/images/beakerpour.gif
# Invalid url
# http://www.inkycircus.com/jargon/images/beaker.jpg
# Invalid url
# http://farm4.static.flickr.com/3038/2585831990_286fe8a27f.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  438.0
# Output idx and class = 438.0 , beaker
# Valid_url 6
# http://farm4.static.flickr.com/3607/3445449920_8dbf1069f9.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  438.0
# Output idx and class = 438.0 , beaker
# Valid_url 7
# http://farm1.static.flickr.com/87/242104856_be9e880eaf.jpg
# No photo
# http://www.cyberattic.com/stores/wgc/items/430728/catphoto.jpg
# Invalid url
# http://product.05120512.com/pic/19/80619.jpg
# Invalid url
# http://i01.c.aliimg.com/img/offer/76/52/79/07/76527907.search.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  438.0
# Output idx and class = 438.0 , beaker
# Valid_url 11
# http://farm1.static.flickr.com/38/123239711_b7ae0a7504.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  457.0
# Output idx and class = 457.0 , bow tie, bow-tie, bowtie
# Valid_url 0
# http://farm4.static.flickr.com/3617/3315841753_cafddd6de3.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  457.0
# Output idx and class = 982.0 , groom, bridegroom
# Diff label 1
# http://farm4.static.flickr.com/3200/3129115508_6a85efb63f.jpg
# No photo
# http://2.bp.blogspot.com/_0sdrdAqyiJ8/RtQQ4eiyMHI/AAAAAAAAA1U/Mj2ZlwKUTrk/s400/bowtie.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  457.0
# Output idx and class = 457.0 , bow tie, bow-tie, bowtie
# Valid_url 3
# http://www.clermontdirect.com/images/burgundy%20bow%20tie%20300.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  457.0
# Output idx and class = 457.0 , bow tie, bow-tie, bowtie
# Valid_url 4
# http://gallery.nofactzone.net/albums/userpics/311721379_746b8f902e_m.jpg
# Invalid url
# http://farm4.static.flickr.com/3224/2860522501_3524caa020.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  457.0
# Output idx and class = 457.0 , bow tie, bow-tie, bowtie
# Valid_url 6
# http://www.dogclothingapparel.com/ZenCart/images/tbt01_bowtie.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  457.0
# Output idx and class = 457.0 , bow tie, bow-tie, bowtie
# Valid_url 7
# http://img.alibaba.com/photo/11612957/Glass_Marble_Candle_Light_Cup.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 719.0 , piggy bank, penny bank
# Diff label 0
# http://www.craftschina.net/main/photo/lacquertec-17114643.jpg
# Invalid url
# http://www.yoyo18.com/web/webPic/20071219203526T0_1.jpg
# Invalid url
# http://img292.imageshack.us/img292/2682/candle2mv8.jpg
# Invalid url
# http://www.countryporch.com/home-accessories/candle/images/three-leg-twist-candle-holder.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 470.0 , candle, taper, wax light
# Valid_url 4
# http://pic.nipic.com/2007-05-30/20075300141626_2.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 470.0 , candle, taper, wax light
# Valid_url 5
# http://www.hotref.com/category/0714/Shell-design-candle-holder-favors_4682_r.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 470.0 , candle, taper, wax light
# Valid_url 6
# http://static.flickr.com/3033/2674621076_afb70de160.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 731.0 , plunger, plumber's helper
# Diff label 7
# http://static.flickr.com/20/70815232_b799e1ad83.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 470.0 , candle, taper, wax light
# Valid_url 8
# http://pic.nipic.com/2007-05-29/2007529213343990_2.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  470.0
# Output idx and class = 470.0 , candle, taper, wax light
# Valid_url 9
# http://farm3.static.flickr.com/2482/3657235879_476815b7a0.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  480.0
# Output idx and class = 707.0 , pay-phone, pay-station
# Diff label 0
# http://farm2.static.flickr.com/1156/989112248_8e0d1e1caa.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  480.0
# Output idx and class = 480.0 , cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM
# Valid_url 1
# http://farm3.static.flickr.com/2032/2035692183_e54e5cb10f.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  480.0
# Output idx and class = 480.0 , cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM
# Valid_url 2
# http://farm4.static.flickr.com/3661/3409719607_26180ae996.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  480.0
# Output idx and class = 480.0 , cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM
# Valid_url 3
# http://lh4.ggpht.com/_yqgp6ddxckQ/RmcrW41N__I/AAAAAAAAAGk/AfU9qMh0ZkM/DSC00473.JPG
# torch.Size([1, 3, 224, 224])
# Original label =  480.0
# Output idx and class = 480.0 , cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM
# Valid_url 4
# http://www.istockphoto.com/file_thumbview_approve/2308885/2/istockphoto_2308885-drive-thru-atm-machine.jpg
# Invalid url
# http://farm2.static.flickr.com/1310/610922665_14c72b59f8.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  480.0
# Output idx and class = 480.0 , cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM
# Valid_url 6
# http://farm4.static.flickr.com/3051/2465818111_39662b5e91.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 491.0 , chain saw, chainsaw
# Valid_url 0
# http://farm4.static.flickr.com/3187/2754683384_1c78544c62.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 870.0 , tricycle, trike, velocipede
# Diff label 1
# http://www.lamotosega.com/images/G3200_large.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 491.0 , chain saw, chainsaw
# Valid_url 2
# http://farm3.static.flickr.com/2407/2498315030_d334dcbb7d.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 707.0 , pay-phone, pay-station
# Diff label 3
# http://www.lamotosega.com/images/G3800_large.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 491.0 , chain saw, chainsaw
# Valid_url 4
# http://farm1.static.flickr.com/26/55110109_61f16d5f3f.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 314.0 , cockroach, roach
# Diff label 5
# http://farm2.static.flickr.com/1401/1438514331_efff2cc815.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 491.0 , chain saw, chainsaw
# Valid_url 6
# http://farm4.static.flickr.com/3196/2842916302_610fb627d3.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  491.0
# Output idx and class = 491.0 , chain saw, chainsaw
# Valid_url 7
# http://farm4.static.flickr.com/3145/2645479889_ce4464eaee.jpg
# No photo
# http://farm3.static.flickr.com/2532/3816345334_6f9c3893c7.jpg
# No photo
# http://www.ssgecom.com/products/images/dbr110_l.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  543.0
# Output idx and class = 543.0 , dumbbell
# Valid_url 2
# http://farm4.static.flickr.com/3234/2282475069_b175cb2c64.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  543.0
# Output idx and class = 543.0 , dumbbell
# Valid_url 3
# http://cn.made-in-china.com/image/2f0j01yevtBQMslrbOM/哑铃.jpg
# Invalid url
# http://farm4.static.flickr.com/3511/3469472927_c2b57467a9.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  543.0
# Output idx and class = 543.0 , dumbbell
# Valid_url 5
# http://www.greater-weightloss.com/dumbbelll-press.jpg
# Invalid url
# http://farm4.static.flickr.com/3403/3439832656_7e5f1b8b24.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  543.0
# Output idx and class = 543.0 , dumbbell
# Valid_url 7
# http://munfitnessblog.com/wp-content/uploads/2007/10/incline-dumbbell-press-for-upper-pectorals-1.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  543.0
# Output idx and class = 422.0 , barbell
# Diff label 8
# http://farm4.static.flickr.com/3069/2934858672_1b7507d0bf.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  543.0
# Output idx and class = 543.0 , dumbbell
# Valid_url 9
# http://www.instrumentalley.com/v/vspfiles/photos/DV-ORC-2T.jpg
# Invalid url
# http://static.howstuffworks.com/gif/eg-body1.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  546.0
# Output idx and class = 546.0 , electric guitar
# Valid_url 1
# http://static.flickr.com/54/154783464_89ef974050.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  546.0
# Output idx and class = 546.0 , electric guitar
# Valid_url 2
# http://www.racerxband.com/pictures/vegas-gh/images/082.%20electric-guitar-room4.jpg
# Invalid url
# http://www.tygerpipes.com/photo/156-0.jpg
# Invalid url
# http://www.a-violin.com/picImg/Electric-Guitar-Jazz-Series-2-Middle.jpg
# Invalid url
# http://www.lacoctelera.com/myfiles/swiblog/5992157.jpg
# Invalid url
# http://www.altoedge.com/guitar/images/usbguitar.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  546.0
# Output idx and class = 546.0 , electric guitar
# Valid_url 7
# http://www.jlstudios.ca/audio_equipment_for_sale/Guitar.gif
# Invalid url
# http://www.thecakestore.co.uk/acatalog/electricguitar.jpg
# Invalid url
# http://www.accessguitar.com/inventory/photos/synson03.jpg
# Invalid url
# http://farm4.static.flickr.com/3012/2911179921_cac301671c.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  546.0
# Output idx and class = 546.0 , electric guitar
# Valid_url 11
# http://farm3.static.flickr.com/2180/1892877059_ff726732dd.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  546.0
# Output idx and class = 546.0 , electric guitar
# Valid_url 12
# http://farm2.static.flickr.com/1427/1265594753_497de96977.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  568.0
# Output idx and class = 568.0 , fur coat
# Valid_url 0
# http://farm4.static.flickr.com/3189/2881930737_a7d9184852.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  568.0
# Output idx and class = 568.0 , fur coat
# Valid_url 1
# http://farm3.static.flickr.com/2265/2278008802_818c2c63cf.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  568.0
# Output idx and class = 568.0 , fur coat
# Valid_url 2
# http://www.4adesign.com/highend/fox_coat_1th.jpg
# Invalid url
# http://farm2.static.flickr.com/1360/757540381_3b668c7ae6.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  568.0
# Output idx and class = 568.0 , fur coat
# Valid_url 4
# http://farm1.static.flickr.com/78/224804890_33a95a32ca.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  568.0
# Output idx and class = 568.0 , fur coat
# Valid_url 5
# http://farm4.static.flickr.com/3325/3284594683_b10619f1c9.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 578.0 , gown
# Valid_url 0
# http://cn.made-in-china.com/image/2f0j01DvCEQkeBHTgAM/西山婚纱、礼服-09.jpg
# Invalid url
# http://farm4.static.flickr.com/3656/3292237413_b2bff241a0.jpg
# No photo
# http://farm1.static.flickr.com/37/87631221_1522958a36.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 982.0 , groom, bridegroom
# Diff label 3
# http://cn.made-in-china.com/image/2f0j01BvJaQKYtJTbqM/儿童礼服+（2007003）.jpg
# Invalid url
# http://magazine.zankyou.com/es/wp-content/uploads/2009/03/victorio_y_lucchino_1.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 601.0 , hoopskirt, crinoline
# Diff label 5
# http://farm4.static.flickr.com/3315/3218393802_04f385b310.jpg
# No photo
# http://farm4.static.flickr.com/3225/2418422551_0379a5b38e.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 406.0 , altar
# Diff label 7
# http://farm2.static.flickr.com/1099/1316790322_e7758f4eec.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 617.0 , lab coat, laboratory coat
# Diff label 8
# http://monjitasalamoda.files.wordpress.com/2009/03/03_vestido_largo_celeste_01.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 578.0 , gown
# Valid_url 9
# http://imagenes.solostocks.com/m11884575/vestido-largo-de-fiesta-ibicenco.jpg
# Invalid url
# http://farm1.static.flickr.com/24/99062021_c843aad331.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 578.0 , gown
# Valid_url 11
# http://cn.made-in-china.com/image/2f0j01uMKEieCyrgovM/礼服，花童装.jpg
# Invalid url
# http://www.elheraldo.hn/var/elheraldo_site/storage/images/ediciones/2009/01/22/multimedia/obama-vestido-con-esmoquin-y-pajarita-blanca-y-michele-con-vestido-largo-color-marfil-fueron-los-anfitriones-de-los-bailes.-la-noche-magica-culmino-bailando/645103-1-esl-HN/Obama-vestido-con-esmoquin-y-pajarita-blanca-y-Michele-con-vestido-largo-color-marfil-fueron-los-anfitriones-de-los-bailes.-La-noche-magica-culmino-bailando_noticia_full.jpg
# Invalid url
# http://img07.taobaocdn.com/bao/uploaded/i7/T1nLpXXlXhWUxVzW6b_123143.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 578.0 , gown
# Valid_url 14
# http://www.adn.es/clipping/ADNIMA20070918_3354/4.jpg
# Invalid url
# http://farm4.static.flickr.com/3296/3052639855_00796b54a3.jpg
# No photo
# http://farm1.static.flickr.com/53/166604748_eafc498a24.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 753.0 , radiator
# Diff label 17
# http://farm4.static.flickr.com/3225/3288554773_c17f41662d.jpg
# No photo
# http://farm4.static.flickr.com/3614/3505955789_c2cf72a914.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 601.0 , hoopskirt, crinoline
# Diff label 19
# http://farm4.static.flickr.com/3449/3256086155_0b314a2639.jpg
# No photo
# http://cn.made-in-china.com/image/2f0j01OVtETtQkRaAbM/婚纱礼服－S011.jpg
# Invalid url
# http://img.diytrade.com/cdimg/490531/3140626/0/1167552381.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  578.0
# Output idx and class = 578.0 , gown
# Valid_url 22
# http://farm3.static.flickr.com/2026/1680636253_d8882d64f5.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  587.0
# Output idx and class = 587.0 , hammer
# Valid_url 0
# http://www.dancingfrogforge.com/HammerLHDiagReforge2lb1_4oz04072007.JPG
# Invalid url
# http://farm4.static.flickr.com/3547/3829124992_d4beae27c5.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  587.0
# Output idx and class = 587.0 , hammer
# Valid_url 2
# http://farm2.static.flickr.com/1123/1455423219_6cc419bd52.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  587.0
# Output idx and class = 587.0 , hammer
# Valid_url 3
# http://farm1.static.flickr.com/136/366219218_24cde355e6.jpg
# No photo
# http://www.bloomertool.com/images/EL1607_1_.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  587.0
# Output idx and class = 587.0 , hammer
# Valid_url 5
# http://greatnecksaw.com/images/product_images/medium/79001.jpg
# Invalid url
# http://businessludhiana.com/imgs/hand11.jpg
# Invalid url
# http://farm1.static.flickr.com/21/32867960_0b0be86629.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  587.0
# Output idx and class = 587.0 , hammer
# Valid_url 8
# http://farm1.static.flickr.com/112/285707642_4f530a250f.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  609.0
# Output idx and class = 609.0 , jeep, landrover
# Valid_url 0
# http://farm2.static.flickr.com/1314/1491197116_2aca40ee62.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  609.0
# Output idx and class = 609.0 , jeep, landrover
# Valid_url 1
# http://farm1.static.flickr.com/46/130009781_932b695535.jpg
# No photo
# http://www.motorpasion.com/archivos/images/land_rover_defender_2007_07.jpg
# Invalid url
# http://content.answers.com/main/content/wp/en-commons/thumb/8/89/250px-1992_Jeep_YJ.JPG
# Invalid url
# http://www.autocult.com.au/img/gallery/full/CARmageddon660.jpg
# Invalid url
# http://farm2.static.flickr.com/1310/684874945_b4e7769fc5.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  609.0
# Output idx and class = 609.0 , jeep, landrover
# Valid_url 6
# http://farm3.static.flickr.com/2331/2410359633_8535ceaae5.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  609.0
# Output idx and class = 609.0 , jeep, landrover
# Valid_url 7
# http://farm3.static.flickr.com/2361/2308153129_68c298fd1c.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  609.0
# Output idx and class = 609.0 , jeep, landrover
# Valid_url 8

# %%
# key = 5
# dset = Data(model,device,class_id_arr5,key)
# val_urls = dset.make_valid_url_list()
# Out:
# http://farm3.static.flickr.com/2056/2124889216_606ee06f19.jpg
# No photo
# http://farm1.static.flickr.com/22/34347807_8465803995.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 526.0 , desk
# Diff label 1
# http://farm2.static.flickr.com/1119/622760513_fae61a4aac.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 620.0 , laptop, laptop computer
# Valid_url 2
# http://www.allproducts.com/manufacture97/laptopbag/product4-s.jpg
# Couldn't load image cannot identify image file <_io.BytesIO object at 0x7f22842257d8>
# http://www.allproducts.com/manufacture97/laptopbag/product4-s.jpg
# Invalid url
# http://farm1.static.flickr.com/59/188110566_ebdd659f37.jpg
# No photo
# http://farm1.static.flickr.com/208/467381047_072a888cb0.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 681.0 , notebook, notebook computer
# Diff label 5
# http://farm1.static.flickr.com/208/506828990_3b47f6cbc9.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 620.0 , laptop, laptop computer
# Valid_url 6
# http://farm3.static.flickr.com/2366/2122482524_32d46f8b14.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 446.0 , binder, ring-binder
# Diff label 7
# http://farm1.static.flickr.com/156/436727181_e2da2337e2.jpg
# No photo
# http://farm1.static.flickr.com/87/263215144_637b9c9097.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 613.0 , joystick
# Diff label 9
# http://farm3.static.flickr.com/2401/2274906634_ab85c5f034.jpg
# No photo
# http://farm1.static.flickr.com/64/209493732_b7c52fc901.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 681.0 , notebook, notebook computer
# Diff label 11
# http://farm3.static.flickr.com/2247/2124890530_1e0e6cdfd8.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 620.0 , laptop, laptop computer
# Valid_url 12
# http://farm1.static.flickr.com/30/59736625_e4219901e4.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 620.0 , laptop, laptop computer
# Valid_url 13
# http://farm1.static.flickr.com/174/416775946_e40873dab2.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  620.0
# Output idx and class = 620.0 , laptop, laptop computer
# Valid_url 14
# http://i03.c.aliimg.com/img/offer/13/57/48/32/8/135748328-2
# torch.Size([1, 3, 224, 224])
# Original label =  629.0
# Output idx and class = 629.0 , lipstick, lip rouge
# Valid_url 0
# http://farm4.static.flickr.com/3604/3351589083_993ab62805.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  629.0
# Output idx and class = 629.0 , lipstick, lip rouge
# Valid_url 1
# http://farm3.static.flickr.com/2412/2178005330_7accbb280c.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  629.0
# Output idx and class = 629.0 , lipstick, lip rouge
# Valid_url 2
# http://farm4.static.flickr.com/3084/2681585991_e1a7e8d156.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  629.0
# Output idx and class = 629.0 , lipstick, lip rouge
# Valid_url 3
# http://img08.taobaocdn.com/bao/uploaded/i8/T1HfRcXnVqwIDaR.sT_013315.jpg_b.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  629.0
# Output idx and class = 629.0 , lipstick, lip rouge
# Valid_url 4
# http://farm3.static.flickr.com/2154/2247234846_2a613cc174.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  637.0
# Output idx and class = 637.0 , mailbox, letter box
# Valid_url 0
# http://farm4.static.flickr.com/3289/3147590515_e816200667.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  637.0
# Output idx and class = 637.0 , mailbox, letter box
# Valid_url 1
# http://farm4.static.flickr.com/3652/3353973378_82d3d430b2.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  637.0
# Output idx and class = 637.0 , mailbox, letter box
# Valid_url 2
# http://farm1.static.flickr.com/45/136561442_e370980685.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  637.0
# Output idx and class = 637.0 , mailbox, letter box
# Valid_url 3
# http://farm4.static.flickr.com/3026/2900720148_ff6c6e38b9.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  637.0
# Output idx and class = 637.0 , mailbox, letter box
# Valid_url 4
# http://farm4.static.flickr.com/3142/3007965680_3bd6869655.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  668.0
# Output idx and class = 668.0 , mosque
# Valid_url 0
# http://www.regione.lazio.it/binary/web/ruota_libera/Beirut_large.1147711525.jpg
# Invalid url
# http://www.andaluciaimagen.com/Mezquita-azul-o-del--rey-Abdullah-Jordania_20681.jpg
# Invalid url
# http://static.flickr.com/31/44234108_16cd3b9834.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  668.0
# Output idx and class = 668.0 , mosque
# Valid_url 3
# http://farm1.static.flickr.com/40/122256574_da8639fd7d.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  668.0
# Output idx and class = 718.0 , pier
# Diff label 4
# http://farm4.static.flickr.com/3087/2653869838_f4b8d2de3c.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  668.0
# Output idx and class = 668.0 , mosque
# Valid_url 5
# http://static.flickr.com/38/122416982_56f41f9188.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  668.0
# Output idx and class = 668.0 , mosque
# Valid_url 6
# http://farm3.static.flickr.com/2082/2255535243_8da96294f0.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  668.0
# Output idx and class = 668.0 , mosque
# Valid_url 7
# http://farm1.static.flickr.com/110/256241997_0028e8bfac.jpg
# No photo
# http://farm3.static.flickr.com/2769/4023971878_241501f590.jpg
# No photo
# http://farm4.static.flickr.com/3260/2800387734_d57dc1dc69.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 696.0 , paintbrush
# Valid_url 2
# http://farm2.static.flickr.com/1101/1461347098_3f00d45683.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 477.0 , carpenter's kit, tool kit
# Diff label 3
# http://farm2.static.flickr.com/1063/571165859_e8c76b0334.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 696.0 , paintbrush
# Valid_url 4
# http://farm4.static.flickr.com/3024/3021836550_fc926dafcb.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 767.0 , rubber eraser, rubber, pencil eraser
# Diff label 5
# http://img.alibaba.com/photo/51817919/Paint_Brush.summ.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 906.0 , Windsor tie
# Diff label 6
# http://farm4.static.flickr.com/3141/3042211467_45ac0d09b7.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 696.0 , paintbrush
# Valid_url 7
# http://farm4.static.flickr.com/3246/2699422019_78eb7ba811.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 767.0 , rubber eraser, rubber, pencil eraser
# Diff label 8
# http://farm2.static.flickr.com/1307/533230580_afd20538e1.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 696.0 , paintbrush
# Valid_url 9
# http://farm4.static.flickr.com/3118/2794358992_c9daa61b30.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 813.0 , spatula
# Diff label 10
# http://z.about.com/d/painting/1/0/2/d/1/Brush-Protectors.jpg
# Invalid url
# http://farm1.static.flickr.com/36/99255502_dba96d589d.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  696.0
# Output idx and class = 696.0 , paintbrush
# Valid_url 12
# http://farm2.static.flickr.com/1041/1281907413_0e42074d31.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  706.0
# Output idx and class = 706.0 , patio, terrace
# Valid_url 0
# http://farm1.static.flickr.com/230/494454848_fcb12ced94.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  706.0
# Output idx and class = 706.0 , patio, terrace
# Valid_url 1
# http://farm1.static.flickr.com/18/69535034_2ecbed3b03.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  706.0
# Output idx and class = 706.0 , patio, terrace
# Valid_url 2
# http://farm4.static.flickr.com/3219/2439107201_3d26655ecb.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  706.0
# Output idx and class = 873.0 , triumphal arch
# Diff label 3
# http://farm1.static.flickr.com/121/284251794_76a45b9e40.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  706.0
# Output idx and class = 706.0 , patio, terrace
# Valid_url 4
# http://farm1.static.flickr.com/60/171011919_198ee456ee.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  706.0
# Output idx and class = 706.0 , patio, terrace
# Valid_url 5
# http://farm4.static.flickr.com/3280/2725177594_7bc8116c69.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 721.0 , pillow
# Valid_url 0
# http://farm4.static.flickr.com/3025/2595242338_6d1fa728bf.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 721.0 , pillow
# Valid_url 1
# http://farm3.static.flickr.com/2230/2494808820_b514eb2c39.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 474.0 , cardigan
# Diff label 2
# http://www.expodirect.es/images/ALMOHADA%20DE%20LANA.jpg
# Invalid url
# http://farm4.static.flickr.com/3499/3829042177_49958ef9de.jpg
# No photo
# http://farm1.static.flickr.com/88/266074805_384623dea0.jpg
# No photo
# http://farm4.static.flickr.com/3199/3287935704_f4ca778a59.jpg
# No photo
# http://farm4.static.flickr.com/3405/3185064411_af1aca8145.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 533.0 , dishrag, dishcloth
# Diff label 7
# http://farm4.static.flickr.com/3296/3046803999_c3ff1d94b4.jpg
# No photo
# http://farm4.static.flickr.com/3268/3253753917_3ab4a118bf.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 431.0 , bassinet
# Diff label 9
# http://farm4.static.flickr.com/3004/3075913230_d60023963e.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 721.0 , pillow
# Valid_url 10
# http://farm5.static.flickr.com/4002/4173078140_fb6f878afb.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 721.0 , pillow
# Valid_url 11
# http://farm4.static.flickr.com/3266/2616447890_243291c619.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 514.0 , cowboy boot
# Diff label 12
# http://farm4.static.flickr.com/3138/2823407746_80f6be9d29.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  721.0
# Output idx and class = 721.0 , pillow
# Valid_url 13
# http://images.replacements.com/images/images5/china/A/john_aynsley_cottage_garden_swirl_salt_pepper_set_P0000003675S0055T2.jpg
# Invalid url
# http://farm1.static.flickr.com/55/388887958_8c693c66a1.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 773.0 , saltshaker, salt shaker
# Valid_url 1
# http://farm2.static.flickr.com/1184/1489401295_fe86c13aec.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 773.0 , saltshaker, salt shaker
# Valid_url 2
# http://farm3.static.flickr.com/2017/1848669629_472fc33044.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 719.0 , piggy bank, penny bank
# Diff label 3
# http://farm1.static.flickr.com/53/131047900_3fc66e1726.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 855.0 , thimble
# Diff label 4
# http://ecx.images-amazon.com/images/I/41MZ435QZXL._SL500_AA280_.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 503.0 , cocktail shaker
# Diff label 5
# http://farm3.static.flickr.com/2172/2230553293_b92cfe14d5.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 773.0 , saltshaker, salt shaker
# Valid_url 6
# http://farm4.static.flickr.com/3404/3182851978_99cd1ea116.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 773.0 , saltshaker, salt shaker
# Valid_url 7
# http://farm4.static.flickr.com/3062/2807491448_d9b9d7fd70.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 626.0 , lighter, light, igniter, ignitor
# Diff label 8
# http://www.mydreammattress.com/images/product/3_5247.jpg
# Invalid url
# http://farm4.static.flickr.com/3239/2886300829_103d8d21fb.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  773.0
# Output idx and class = 773.0 , saltshaker, salt shaker
# Valid_url 10
# http://farm4.static.flickr.com/3371/3303636375_995af36f37.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  806.0
# Output idx and class = 806.0 , sock
# Valid_url 0
# http://farm2.static.flickr.com/1100/770775553_9dc1db4e6e.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  806.0
# Output idx and class = 806.0 , sock
# Valid_url 1
# http://farm1.static.flickr.com/154/423760858_1e8b34a98d.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  806.0
# Output idx and class = 109.0 , brain coral
# Diff label 2
# http://farm4.static.flickr.com/3219/3069316770_06ba78e528.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  806.0
# Output idx and class = 806.0 , sock
# Valid_url 3
# http://farm4.static.flickr.com/3230/2702906247_77c82b762c.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  806.0
# Output idx and class = 806.0 , sock
# Valid_url 4
# http://farm4.static.flickr.com/3008/2823164296_44bd8aac51.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  806.0
# Output idx and class = 806.0 , sock
# Valid_url 5
# http://farm4.static.flickr.com/3112/2587275741_7e092c2f39.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 763.0 , revolver, six-gun, six-shooter
# Diff label 0
# http://farm1.static.flickr.com/207/485218051_82ab6fc02a.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 27.0 , eft
# Diff label 1
# http://farm4.static.flickr.com/3275/2373716348_d94f3c3969.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 845.0 , syringe
# Valid_url 2
# http://farm1.static.flickr.com/42/86785295_3041631d42.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 845.0 , syringe
# Valid_url 3
# http://farm4.static.flickr.com/3108/3161882451_bbb4e55a12.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 845.0 , syringe
# Valid_url 4
# http://farm1.static.flickr.com/115/275143864_a050efe478.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 731.0 , plunger, plumber's helper
# Diff label 5
# http://farm2.static.flickr.com/1178/1406165059_9ba1a765bb.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 623.0 , letter opener, paper knife, paperknife
# Diff label 6
# http://farm1.static.flickr.com/121/286123157_4edbd325d3.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 845.0 , syringe
# Valid_url 7
# http://farm4.static.flickr.com/3141/2329669946_c4179b11d8.jpg
# No photo
# http://farm1.static.flickr.com/180/415433543_dea9c202a4.jpg
# torch.Size([1, 3, 224, 224])
# Original label =  845.0
# Output idx and class = 845.0 , syringe
# Valid_url 9
